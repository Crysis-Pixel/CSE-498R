# %% [markdown]
# ## Test on Novels

# %%
import pandas as pd
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
from tokenizers import ByteLevelBPETokenizer
import torch.nn as nn
from transformers import get_cosine_schedule_with_warmup

# === Load Data ===
df = pd.read_csv("final_dataset.csv")

# Keep only "human" and "ai" labels
df = df[df['label'].isin(['human', 'ai'])]
label_map = {"human": 0, "ai": 1}
df["label"] = df["label"].map(label_map)

# === Split based on 'category' ===
train_categories = ["poems", "stories", "essays"]
test_categories  = ["novels"]

train_df = df[df["category"].isin(train_categories)]
test_df  = df[df["category"].isin(test_categories)]

# Split validation (10% from training set)
train_texts, val_texts, train_labels, val_labels = train_test_split(
    train_df["text"].tolist(),
    train_df["label"].tolist(),
    test_size=0.1,
    stratify=train_df["label"].tolist(),
    random_state=42
)

test_texts, test_labels = test_df["text"].tolist(), test_df["label"].tolist()

# === Prepare dynamic naming ===
train_cat_str = "_".join(train_categories)
test_cat_str  = "_".join(test_categories)

modelPath = f"best_model_train_{train_cat_str}_test_{test_cat_str}.pt"
loss_graph_path = f"loss_graph_train_{train_cat_str}_test_{test_cat_str}.png"
accuracy_graph_path = f"accuracy_graph_train_{train_cat_str}_test_{test_cat_str}.png"
confusion_matrix_path = f"confusion_matrix_train_{train_cat_str}_test_{test_cat_str}.png"

# === Plot label distribution ===
splits = {
    "Train": train_labels,
    "Validation": val_labels,
    f"Test ({', '.join(test_categories)})": test_labels,
}

fig, axs = plt.subplots(1, 3, figsize=(15, 5))
for i, (split_name, split_labels) in enumerate(splits.items()):
    counts = pd.Series(split_labels).value_counts().sort_index()
    class_names = ['Human', 'AI']
    sns.barplot(x=class_names, y=counts.values, ax=axs[i], palette="pastel")
    axs[i].set_title(f"{split_name} Set")
    axs[i].set_ylabel("Count")
    axs[i].set_ylim(0, max(counts.values) * 1.2)
    for j, count in enumerate(counts.values):
        axs[i].text(j, count + 2, str(count), ha='center', va='bottom', fontsize=10)
plt.tight_layout()
plt.suptitle("Label Distribution Across Splits", fontsize=16, y=1.05)
plt.show()

# === Tokenizer ===
tokenizerPath = "tokenizer_path"
if not os.path.exists(tokenizerPath):
    os.makedirs(tokenizerPath)
    tokenizer = ByteLevelBPETokenizer()
    tokenizer.train_from_iterator(train_texts, vocab_size=30000, min_frequency=2,
                                  special_tokens=["[PAD]", "[UNK]", "[CLS]", "[SEP]"])
    tokenizer.save_model(tokenizerPath)
else:
    tokenizer = ByteLevelBPETokenizer(f"{tokenizerPath}/vocab.json", f"{tokenizerPath}/merges.txt")

# === Hyperparameters ===
max_length = 128
batch_size = 32
device = "cuda" if torch.cuda.is_available() else "cpu"
learning_rate = 2e-5
num_epochs = 50
patience = 20

# === Encode function ===
def encode_batch(texts):
    encodings = tokenizer.encode_batch(texts)
    input_ids, attention_masks = [], []
    for e in encodings:
        ids = e.ids[:max_length] + [0] * (max_length - len(e.ids)) if len(e.ids) < max_length else e.ids[:max_length]
        mask = [1] * min(len(e.ids), max_length) + [0] * (max_length - len(e.ids))
        input_ids.append(ids)
        attention_masks.append(mask)
    return torch.tensor(input_ids), torch.tensor(attention_masks)

# === Dataset ===
class BengaliTextDataset(Dataset):
    def __init__(self, texts, labels):
        self.input_ids, self.attention_mask = encode_batch(texts)
        self.labels = torch.tensor(labels)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return {
            "input_ids": self.input_ids[idx],
            "attention_mask": self.attention_mask[idx],
            "labels": self.labels[idx]
        }

train_dataset = BengaliTextDataset(train_texts, train_labels)
val_dataset   = BengaliTextDataset(val_texts, val_labels)
test_dataset  = BengaliTextDataset(test_texts, test_labels)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=batch_size)
test_loader  = DataLoader(test_dataset, batch_size=batch_size)

# === Model ===
class CustomTransformer(nn.Module):
    def __init__(self, vocab_size, max_len=128, d_model=512, nhead=8,
                 num_layers=6, dim_feedforward=2048, num_classes=2):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.position_embedding = nn.Embedding(max_len, d_model)
        encoder_layer = nn.TransformerEncoderLayer(d_model, nhead, dim_feedforward,
                                                   dropout=0.3, batch_first=True)
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers)
        self.dropout = nn.Dropout(0.3)
        self.classifier = nn.Sequential(
            nn.Linear(d_model, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, num_classes)
        )

    def forward(self, input_ids, attention_mask):
        positions = torch.arange(0, input_ids.size(1), device=input_ids.device).unsqueeze(0)
        x = self.embedding(input_ids) + self.position_embedding(positions)
        x = self.encoder(x, src_key_padding_mask=~attention_mask.bool())
        x = self.dropout(x[:, 0])
        return self.classifier(x)

vocab_size = tokenizer.get_vocab_size()
model = CustomTransformer(vocab_size=vocab_size).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
loss_fn = nn.CrossEntropyLoss(label_smoothing=0.1)

# Scheduler
warmup_steps = 500
total_steps = len(train_loader) * num_epochs
scheduler = get_cosine_schedule_with_warmup(optimizer, warmup_steps, total_steps)

# === Training ===
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []
best_val_acc = 0
best_epoch = 0
early_stop_counter = 0

for epoch in range(num_epochs):
    print(f"\nEpoch {epoch+1}/{num_epochs}")
    model.train()
    total_train_loss, correct, total = 0, 0, 0
    for batch in tqdm(train_loader, desc="Training"):
        optimizer.zero_grad()
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        outputs = model(input_ids, attention_mask)
        loss = loss_fn(outputs, labels)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()
        total_train_loss += loss.item()

        preds = torch.argmax(outputs, dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    train_loss = total_train_loss / len(train_loader)
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)

    # Validation
    model.eval()
    total_val_loss = 0
    all_preds, all_labels = [], []
    with torch.no_grad():
        for batch in tqdm(val_loader, desc="Evaluating"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)
            outputs = model(input_ids, attention_mask)
            loss = loss_fn(outputs, labels)
            total_val_loss += loss.item()
            preds = torch.argmax(outputs, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    val_loss = total_val_loss / len(val_loader)
    val_acc = np.mean(np.array(all_preds) == np.array(all_labels))
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)

    print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f}")
    print(f"Val   Loss: {val_loss:.4f} | Val   Acc: {val_acc:.4f}")

    # Save best model
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_epoch = epoch
        torch.save(model.state_dict(), modelPath)
        print(f"Saved new best model: {modelPath}")
        early_stop_counter = 0
    else:
        early_stop_counter += 1
        print(f"Early stop counter: {early_stop_counter}/{patience}")

    if early_stop_counter >= patience:
        print(f"\nEarly stopping at epoch {epoch+1}. Best epoch was {best_epoch+1}.")
        break

# === Plot Loss & Accuracy ===
epochs = range(1, len(train_losses) + 1)
plt.figure(figsize=(8, 5))
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, val_losses, label='Validation Loss')
plt.axvline(best_epoch + 1, linestyle='--', color='r', label='Best Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()
plt.grid(True)
plt.savefig(loss_graph_path)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(epochs, train_accuracies, label='Train Accuracy')
plt.plot(epochs, val_accuracies, label='Validation Accuracy')
plt.axvline(best_epoch + 1, linestyle='--', color='r', label='Best Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()
plt.grid(True)
plt.savefig(accuracy_graph_path)
plt.show()

# === Load best model and evaluate on test set ===
model.load_state_dict(torch.load(modelPath))
model.eval()

def evaluate(loader):
    model.eval()
    total_loss = 0
    all_preds, all_labels = [], []
    with torch.no_grad():
        for batch in tqdm(loader, desc="Evaluating"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)
            outputs = model(input_ids, attention_mask)
            loss = loss_fn(outputs, labels)
            total_loss += loss.item()
            preds = torch.argmax(outputs, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    acc = np.mean(np.array(all_preds) == np.array(all_labels))
    return total_loss / len(loader), acc, all_preds, all_labels

print(f"\n🔍 Final Evaluation on Test Set ({', '.join(test_categories)}):")
test_loss, test_acc, test_preds, test_labels = evaluate(test_loader)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}")

# Confusion Matrix & Classification Report
class_names = ["human", "AI"]
cm = confusion_matrix(test_labels, test_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap="Blues", xticks_rotation=45)
plt.title(f"Test Confusion Matrix ({', '.join(test_categories)})")
plt.grid(False)
plt.savefig(confusion_matrix_path)
plt.show()

print("\nClassification Report:")
print(classification_report(test_labels, test_preds, target_names=class_names, digits=4))
# Out:
# /var/folders/g1/2lrwn79x3sd_lxd88z8hyfyc0000gn/T/ipykernel_11149/2310800242.py:61: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_names, y=counts.values, ax=axs[i], palette="pastel")
# /var/folders/g1/2lrwn79x3sd_lxd88z8hyfyc0000gn/T/ipykernel_11149/2310800242.py:61: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_names, y=counts.values, ax=axs[i], palette="pastel")
# /var/folders/g1/2lrwn79x3sd_lxd88z8hyfyc0000gn/T/ipykernel_11149/2310800242.py:61: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_names, y=counts.values, ax=axs[i], palette="pastel")
# Epoch 1/50
# Training: 100%|███████████████████████████████| 507/507 [15:24<00:00,  1.82s/it]
# /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/transformer.py:508: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. We recommend specifying layout=torch.jagged when constructing a nested tensor, as this layout receives active development, has better operator coverage, and works with torch.compile. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/NestedTensorImpl.cpp:182.)
#   output = torch._nested_tensor_from_mask(
# Evaluating: 100%|███████████████████████████████| 57/57 [00:24<00:00,  2.29it/s]
# Train Loss: 0.6039 | Train Acc: 0.6575
# Val   Loss: 0.3675 | Val   Acc: 0.8906
# Saved new best model: best_model_train_poems_stories_essays_test_novels.pt
#
# Epoch 2/50
# Training: 100%|███████████████████████████████| 507/507 [16:11<00:00,  1.92s/it]
# Evaluating: 100%|███████████████████████████████| 57/57 [00:27<00:00,  2.05it/s]
# Train Loss: 0.3548 | Train Acc: 0.9027
# Val   Loss: 0.3157 | Val   Acc: 0.9300
# Saved new best model: best_model_train_poems_stories_essays_test_novels.pt
#
# Epoch 3/50
# Training: 100%|███████████████████████████████| 507/507 [17:42<00:00,  2.10s/it]
# Evaluating: 100%|███████████████████████████████| 57/57 [00:28<00:00,  2.00it/s]
# Train Loss: 0.3150 | Train Acc: 0.9312
# Val   Loss: 0.2994 | Val   Acc: 0.9389
# Saved new best model: best_model_train_poems_stories_essays_test_novels.pt
#
# Epoch 4/50
# Training: 100%|███████████████████████████████| 507/507 [18:04<00:00,  2.14s/it]
# Evaluating: 100%|███████████████████████████████| 57/57 [00:28<00:00,  1.97it/s]
# Train Loss: 0.2937 | Train Acc: 0.9454
# Val   Loss: 0.3002 | Val   Acc: 0.9417
# Saved new best model: best_model_train_poems_stories_essays_test_novels.pt
#
# Epoch 5/50
# Training: 100%|███████████████████████████████| 507/507 [18:13<00:00,  2.16s/it]
# Evaluating: 100%|███████████████████████████████| 57/57 [00:29<00:00,  1.95it/s]
# Train Loss: 0.2761 | Train Acc: 0.9557
# Val   Loss: 0.2828 | Val   Acc: 0.9517
# Saved new best model: best_model_train_poems_stories_essays_test_novels.pt
#
# Epoch
/it]
# Evaluating: 100%|███████████████████████████████| 57/57 [00:31<00:00,  1.81it/s]
# Train Loss: 0.2051 | Train Acc: 0.9977
# Val   Loss: 0.3011 | Val   Acc: 0.9583
# Early stop counter: 17/20
#
# Epoch 31/50
# Training: 100%|███████████████████████████████| 507/507 [17:10<00:00,  2.03s/it]
# Evaluating: 100%|███████████████████████████████| 57/57 [00:27<00:00,  2.06it/s]
# Train Loss: 0.2039 | Train Acc: 0.9982
# Val   Loss: 0.2870 | Val   Acc: 0.9650
# Early stop counter: 18/20
#
# Epoch 32/50
# Training: 100%|███████████████████████████████| 507/507 [18:13<00:00,  2.16s/it]
# Evaluating: 100%|███████████████████████████████| 57/57 [00:30<00:00,  1.87it/s]
# Train Loss: 0.2043 | Train Acc: 0.9981
# Val   Loss: 0.2962 | Val   Acc: 0.9600
# Early stop counter: 19/20
#
# Epoch 33/50
# Training: 100%|███████████████████████████████| 507/507 [16:10<00:00,  1.91s/it]
# Evaluating: 100%|███████████████████████████████| 57/57 [00:26<00:00,  2.15it/s]
# Train Loss: 0.2037 | Train Acc: 0.9983
# Val   Loss: 0.2885 | Val   Acc: 0.9622
# Early stop counter: 20/20
#
# Early stopping at epoch 33. Best epoch was 13.
# 🔍 Final Evaluation on Test Set (novels):
# Evaluating: 100%|█████████████████████████████| 188/188 [01:29<00:00,  2.10it/s]
# Test Loss: 0.3236, Test Accuracy: 0.9403
# Classification Report:
#               precision    recall  f1-score   support
#
#        human     0.9383    0.9427    0.9405      3000
#           AI     0.9424    0.9380    0.9402      3000
#
#     accuracy                         0.9403      6000
#    macro avg     0.9403    0.9403    0.9403      6000
# weighted avg     0.9403    0.9403    0.9403      6000

# %% [markdown]
# # Test on Poems

# %%
import pandas as pd
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
from tokenizers import ByteLevelBPETokenizer
import torch.nn as nn
from transformers import get_cosine_schedule_with_warmup

# === Load Data ===
df = pd.read_csv("/kaggle/input/fianl-dataset/final_dataset.csv")

# Keep only "human" and "ai" labels
df = df[df['label'].isin(['human', 'ai'])]
label_map = {"human": 0, "ai": 1}
df["label"] = df["label"].map(label_map)

# === Split based on 'category' ===
train_categories = ["novels", "stories", "essays"]
test_categories  = ["poems"]

train_df = df[df["category"].isin(train_categories)]
test_df  = df[df["category"].isin(test_categories)]

# Split validation (10% from training set)
train_texts, val_texts, train_labels, val_labels = train_test_split(
    train_df["text"].tolist(),
    train_df["label"].tolist(),
    test_size=0.1,
    stratify=train_df["label"].tolist(),
    random_state=42
)

test_texts, test_labels = test_df["text"].tolist(), test_df["label"].tolist()

# === Prepare dynamic naming ===
train_cat_str = "_".join(train_categories)
test_cat_str  = "_".join(test_categories)

modelPath = f"best_model_train_{train_cat_str}_test_{test_cat_str}.pt"
loss_graph_path = f"loss_graph_train_{train_cat_str}_test_{test_cat_str}.png"
accuracy_graph_path = f"accuracy_graph_train_{train_cat_str}_test_{test_cat_str}.png"
confusion_matrix_path = f"confusion_matrix_train_{train_cat_str}_test_{test_cat_str}.png"

# === Plot label distribution ===
splits = {
    "Train": train_labels,
    "Validation": val_labels,
    f"Test ({', '.join(test_categories)})": test_labels,
}

fig, axs = plt.subplots(1, 3, figsize=(15, 5))
for i, (split_name, split_labels) in enumerate(splits.items()):
    counts = pd.Series(split_labels).value_counts().sort_index()
    class_names = ['Human', 'AI']
    sns.barplot(x=class_names, y=counts.values, ax=axs[i], palette="pastel")
    axs[i].set_title(f"{split_name} Set")
    axs[i].set_ylabel("Count")
    axs[i].set_ylim(0, max(counts.values) * 1.2)
    for j, count in enumerate(counts.values):
        axs[i].text(j, count + 2, str(count), ha='center', va='bottom', fontsize=10)
plt.tight_layout()
plt.suptitle("Label Distribution Across Splits", fontsize=16, y=1.05)
plt.show()

# === Tokenizer ===
tokenizerPath = "tokenizer_path"
if not os.path.exists(tokenizerPath):
    os.makedirs(tokenizerPath)
    tokenizer = ByteLevelBPETokenizer()
    tokenizer.train_from_iterator(train_texts, vocab_size=30000, min_frequency=2,
                                  special_tokens=["[PAD]", "[UNK]", "[CLS]", "[SEP]"])
    tokenizer.save_model(tokenizerPath)
else:
    tokenizer = ByteLevelBPETokenizer(f"{tokenizerPath}/vocab.json", f"{tokenizerPath}/merges.txt")

# === Hyperparameters ===
max_length = 128
batch_size = 32
device = "cuda" if torch.cuda.is_available() else "cpu"
learning_rate = 2e-5
num_epochs = 50
patience = 8

# === Encode function ===
def encode_batch(texts):
    encodings = tokenizer.encode_batch(texts)
    input_ids, attention_masks = [], []
    for e in encodings:
        ids = e.ids[:max_length] + [0] * (max_length - len(e.ids)) if len(e.ids) < max_length else e.ids[:max_length]
        mask = [1] * min(len(e.ids), max_length) + [0] * (max_length - len(e.ids))
        input_ids.append(ids)
        attention_masks.append(mask)
    return torch.tensor(input_ids), torch.tensor(attention_masks)

# === Dataset ===
class BengaliTextDataset(Dataset):
    def __init__(self, texts, labels):
        self.input_ids, self.attention_mask = encode_batch(texts)
        self.labels = torch.tensor(labels)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return {
            "input_ids": self.input_ids[idx],
            "attention_mask": self.attention_mask[idx],
            "labels": self.labels[idx]
        }

train_dataset = BengaliTextDataset(train_texts, train_labels)
val_dataset   = BengaliTextDataset(val_texts, val_labels)
test_dataset  = BengaliTextDataset(test_texts, test_labels)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=batch_size)
test_loader  = DataLoader(test_dataset, batch_size=batch_size)

# === Model ===
class CustomTransformer(nn.Module):
    def __init__(self, vocab_size, max_len=128, d_model=512, nhead=8,
                 num_layers=6, dim_feedforward=2048, num_classes=2):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.position_embedding = nn.Embedding(max_len, d_model)
        encoder_layer = nn.TransformerEncoderLayer(d_model, nhead, dim_feedforward,
                                                   dropout=0.3, batch_first=True)
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers)
        self.dropout = nn.Dropout(0.3)
        self.classifier = nn.Sequential(
            nn.Linear(d_model, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, num_classes)
        )

    def forward(self, input_ids, attention_mask):
        positions = torch.arange(0, input_ids.size(1), device=input_ids.device).unsqueeze(0)
        x = self.embedding(input_ids) + self.position_embedding(positions)
        x = self.encoder(x, src_key_padding_mask=~attention_mask.bool())
        x = self.dropout(x[:, 0])
        return self.classifier(x)

vocab_size = tokenizer.get_vocab_size()
model = CustomTransformer(vocab_size=vocab_size).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
loss_fn = nn.CrossEntropyLoss(label_smoothing=0.1)

# Scheduler
warmup_steps = 500
total_steps = len(train_loader) * num_epochs
scheduler = get_cosine_schedule_with_warmup(optimizer, warmup_steps, total_steps)

# === Training ===
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []
best_val_acc = 0
best_epoch = 0
early_stop_counter = 0

for epoch in range(num_epochs):
    print(f"\nEpoch {epoch+1}/{num_epochs}")
    model.train()
    total_train_loss, correct, total = 0, 0, 0
    for batch in tqdm(train_loader, desc="Training"):
        optimizer.zero_grad()
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        outputs = model(input_ids, attention_mask)
        loss = loss_fn(outputs, labels)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()
        total_train_loss += loss.item()

        preds = torch.argmax(outputs, dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    train_loss = total_train_loss / len(train_loader)
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)

    # Validation
    model.eval()
    total_val_loss = 0
    all_preds, all_labels = [], []
    with torch.no_grad():
        for batch in tqdm(val_loader, desc="Evaluating"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)
            outputs = model(input_ids, attention_mask)
            loss = loss_fn(outputs, labels)
            total_val_loss += loss.item()
            preds = torch.argmax(outputs, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    val_loss = total_val_loss / len(val_loader)
    val_acc = np.mean(np.array(all_preds) == np.array(all_labels))
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)

    print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f}")
    print(f"Val   Loss: {val_loss:.4f} | Val   Acc: {val_acc:.4f}")

    # Save best model
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_epoch = epoch
        torch.save(model.state_dict(), modelPath)
        print(f"Saved new best model: {modelPath}")
        early_stop_counter = 0
    else:
        early_stop_counter += 1
        print(f"Early stop counter: {early_stop_counter}/{patience}")

    if early_stop_counter >= patience:
        print(f"\nEarly stopping at epoch {epoch+1}. Best epoch was {best_epoch+1}.")
        break

# === Plot Loss & Accuracy ===
epochs = range(1, len(train_losses) + 1)
plt.figure(figsize=(8, 5))
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, val_losses, label='Validation Loss')
plt.axvline(best_epoch + 1, linestyle='--', color='r', label='Best Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()
plt.grid(True)
plt.savefig(loss_graph_path)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(epochs, train_accuracies, label='Train Accuracy')
plt.plot(epochs, val_accuracies, label='Validation Accuracy')
plt.axvline(best_epoch + 1, linestyle='--', color='r', label='Best Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()
plt.grid(True)
plt.savefig(accuracy_graph_path)
plt.show()

# === Load best model and evaluate on test set ===
model.load_state_dict(torch.load(modelPath))
model.eval()

def evaluate(loader):
    model.eval()
    total_loss = 0
    all_preds, all_labels = [], []
    with torch.no_grad():
        for batch in tqdm(loader, desc="Evaluating"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)
            outputs = model(input_ids, attention_mask)
            loss = loss_fn(outputs, labels)
            total_loss += loss.item()
            preds = torch.argmax(outputs, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    acc = np.mean(np.array(all_preds) == np.array(all_labels))
    return total_loss / len(loader), acc, all_preds, all_labels

print(f"\n🔍 Final Evaluation on Test Set ({', '.join(test_categories)}):")
test_loss, test_acc, test_preds, test_labels = evaluate(test_loader)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}")

# Confusion Matrix & Classification Report
class_names = ["human", "AI"]
cm = confusion_matrix(test_labels, test_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap="Blues", xticks_rotation=45)
plt.title(f"
50
# Training: 100%|██████████| 507/507 [03:48<00:00,  2.21it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.00it/s]
# Train Loss: 0.2211 | Train Acc: 0.9899
# Val   Loss: 0.3229 | Val   Acc: 0.9500
# Early stop counter: 2/8
#
# Epoch 16/50
# Training: 100%|██████████| 507/507 [03:50<00:00,  2.20it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.14it/s]
# Train Loss: 0.2213 | Train Acc: 0.9898
# Val   Loss: 0.3103 | Val   Acc: 0.9494
# Early stop counter: 3/8
#
# Epoch 17/50
# Training: 100%|██████████| 507/507 [03:51<00:00,  2.19it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.24it/s]
# Train Loss: 0.2167 | Train Acc: 0.9922
# Val   Loss: 0.3138 | Val   Acc: 0.9544
# Saved new best model: best_model_train_novels_stories_essays_test_poems.pt
#
# Epoch 18/50
# Training: 100%|██████████| 507/507 [03:51<00:00,  2.19it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  4.87it/s]
# Train Loss: 0.2188 | Train Acc: 0.9912
# Val   Loss: 0.3125 | Val   Acc: 0.9522
# Early stop counter: 1/8
#
# Epoch 19/50
# Training: 100%|██████████| 507/507 [03:49<00:00,  2.21it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.16it/s]
# Train Loss: 0.2143 | Train Acc: 0.9935
# Val   Loss: 0.3191 | Val   Acc: 0.9506
# Early stop counter: 2/8
#
# Epoch 20/50
# Training: 100%|██████████| 507/507 [03:48<00:00,  2.22it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.30it/s]
# Train Loss: 0.2126 | Train Acc: 0.9941
# Val   Loss: 0.3082 | Val   Acc: 0.9539
# Early stop counter: 3/8
#
# Epoch 21/50
# Training: 100%|██████████| 507/507 [03:46<00:00,  2.23it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.32it/s]
# Train Loss: 0.2113 | Train Acc: 0.9946
# Val   Loss: 0.3207 | Val   Acc: 0.9472
# Early stop counter: 4/8
#
# Epoch 22/50
# Training: 100%|██████████| 507/507 [03:47<00:00,  2.23it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.13it/s]
# Train Loss: 0.2106 | Train Acc: 0.9951
# Val   Loss: 0.3300 | Val   Acc: 0.9478
# Early stop counter: 5/8
#
# Epoch 23/50
# Training: 100%|██████████| 507/507 [03:49<00:00,  2.21it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.29it/s]
# Train Loss: 0.2093 | Train Acc: 0.9961
# Val   Loss: 0.3178 | Val   Acc: 0.9522
# Early stop counter: 6/8
#
# Epoch 24/50
# Training: 100%|██████████| 507/507 [03:46<00:00,  2.24it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.30it/s]
# Train Loss: 0.2090 | Train Acc: 0.9960
# Val   Loss: 0.3420 | Val   Acc: 0.9450
# Early stop counter: 7/8
#
# Epoch 25/50
# Training: 100%|██████████| 507/507 [03:46<00:00,  2.24it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.06it/s]
# Train Loss: 0.2096 | Train Acc: 0.9956
# Val   Loss: 0.3139 | Val   Acc: 0.9517
# Early stop counter: 8/8
#
# Early stopping at epoch 25. Best epoch was 17.
# 🔍 Final Evaluation on Test Set (poems):
# Evaluating: 100%|██████████| 188/188 [00:36<00:00,  5.13it/s]
# Test Loss: 1.4373, Test Accuracy: 0.5392
# Classification Report:
#               precision    recall  f1-score   support
#
#        human     0.9916    0.0790    0.1463      3000
#           AI     0.5204    0.9993    0.6844      3000
#
#     accuracy                         0.5392      6000
#    macro avg     0.7560    0.5392    0.4154      6000
# weighted avg     0.7560    0.5392    0.4154      6000

# %% [markdown]
# ## Test on Essays

# %%
import pandas as pd
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
from tokenizers import ByteLevelBPETokenizer
import torch.nn as nn
from transformers import get_cosine_schedule_with_warmup

# === Load Data ===
df = pd.read_csv("/kaggle/input/fianl-dataset/final_dataset.csv")

# Keep only "human" and "ai" labels
df = df[df['label'].isin(['human', 'ai'])]
label_map = {"human": 0, "ai": 1}
df["label"] = df["label"].map(label_map)

# === Split based on 'category' ===
train_categories = ["novels", "stories", "poems"]
test_categories  = ["essays"]

train_df = df[df["category"].isin(train_categories)]
test_df  = df[df["category"].isin(test_categories)]

# Split validation (10% from training set)
train_texts, val_texts, train_labels, val_labels = train_test_split(
    train_df["text"].tolist(),
    train_df["label"].tolist(),
    test_size=0.1,
    stratify=train_df["label"].tolist(),
    random_state=42
)

test_texts, test_labels = test_df["text"].tolist(), test_df["label"].tolist()

# === Prepare dynamic naming ===
train_cat_str = "_".join(train_categories)
test_cat_str  = "_".join(test_categories)

modelPath = f"best_model_train_{train_cat_str}_test_{test_cat_str}.pt"
loss_graph_path = f"loss_graph_train_{train_cat_str}_test_{test_cat_str}.png"
accuracy_graph_path = f"accuracy_graph_train_{train_cat_str}_test_{test_cat_str}.png"
confusion_matrix_path = f"confusion_matrix_train_{train_cat_str}_test_{test_cat_str}.png"

# === Plot label distribution ===
splits = {
    "Train": train_labels,
    "Validation": val_labels,
    f"Test ({', '.join(test_categories)})": test_labels,
}

fig, axs = plt.subplots(1, 3, figsize=(15, 5))
for i, (split_name, split_labels) in enumerate(splits.items()):
    counts = pd.Series(split_labels).value_counts().sort_index()
    class_names = ['Human', 'AI']
    sns.barplot(x=class_names, y=counts.values, ax=axs[i], palette="pastel")
    axs[i].set_title(f"{split_name} Set")
    axs[i].set_ylabel("Count")
    axs[i].set_ylim(0, max(counts.values) * 1.2)
    for j, count in enumerate(counts.values):
        axs[i].text(j, count + 2, str(count), ha='center', va='bottom', fontsize=10)
plt.tight_layout()
plt.suptitle("Label Distribution Across Splits", fontsize=16, y=1.05)
plt.show()

# === Tokenizer ===
tokenizerPath = "tokenizer_path"
if not os.path.exists(tokenizerPath):
    os.makedirs(tokenizerPath)
    tokenizer = ByteLevelBPETokenizer()
    tokenizer.train_from_iterator(train_texts, vocab_size=30000, min_frequency=2,
                                  special_tokens=["[PAD]", "[UNK]", "[CLS]", "[SEP]"])
    tokenizer.save_model(tokenizerPath)
else:
    tokenizer = ByteLevelBPETokenizer(f"{tokenizerPath}/vocab.json", f"{tokenizerPath}/merges.txt")

# === Hyperparameters ===
max_length = 128
batch_size = 32
device = "cuda" if torch.cuda.is_available() else "cpu"
learning_rate = 2e-5
num_epochs = 50
patience = 8

# === Encode function ===
def encode_batch(texts):
    encodings = tokenizer.encode_batch(texts)
    input_ids, attention_masks = [], []
    for e in encodings:
        ids = e.ids[:max_length] + [0] * (max_length - len(e.ids)) if len(e.ids) < max_length else e.ids[:max_length]
        mask = [1] * min(len(e.ids), max_length) + [0] * (max_length - len(e.ids))
        input_ids.append(ids)
        attention_masks.append(mask)
    return torch.tensor(input_ids), torch.tensor(attention_masks)

# === Dataset ===
class BengaliTextDataset(Dataset):
    def __init__(self, texts, labels):
        self.input_ids, self.attention_mask = encode_batch(texts)
        self.labels = torch.tensor(labels)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return {
            "input_ids": self.input_ids[idx],
            "attention_mask": self.attention_mask[idx],
            "labels": self.labels[idx]
        }

train_dataset = BengaliTextDataset(train_texts, train_labels)
val_dataset   = BengaliTextDataset(val_texts, val_labels)
test_dataset  = BengaliTextDataset(test_texts, test_labels)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=batch_size)
test_loader  = DataLoader(test_dataset, batch_size=batch_size)

# === Model ===
class CustomTransformer(nn.Module):
    def __init__(self, vocab_size, max_len=128, d_model=512, nhead=8,
                 num_layers=6, dim_feedforward=2048, num_classes=2):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.position_embedding = nn.Embedding(max_len, d_model)
        encoder_layer = nn.TransformerEncoderLayer(d_model, nhead, dim_feedforward,
                                                   dropout=0.3, batch_first=True)
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers)
        self.dropout = nn.Dropout(0.3)
        self.classifier = nn.Sequential(
            nn.Linear(d_model, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, num_classes)
        )

    def forward(self, input_ids, attention_mask):
        positions = torch.arange(0, input_ids.size(1), device=input_ids.device).unsqueeze(0)
        x = self.embedding(input_ids) + self.position_embedding(positions)
        x = self.encoder(x, src_key_padding_mask=~attention_mask.bool())
        x = self.dropout(x[:, 0])
        return self.classifier(x)

vocab_size = tokenizer.get_vocab_size()
model = CustomTransformer(vocab_size=vocab_size).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
loss_fn = nn.CrossEntropyLoss(label_smoothing=0.1)

# Scheduler
warmup_steps = 500
total_steps = len(train_loader) * num_epochs
scheduler = get_cosine_schedule_with_warmup(optimizer, warmup_steps, total_steps)

# === Training ===
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []
best_val_acc = 0
best_epoch = 0
early_stop_counter = 0

for epoch in range(num_epochs):
    print(f"\nEpoch {epoch+1}/{num_epochs}")
    model.train()
    total_train_loss, correct, total = 0, 0, 0
    for batch in tqdm(train_loader, desc="Training"):
        optimizer.zero_grad()
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        outputs = model(input_ids, attention_mask)
        loss = loss_fn(outputs, labels)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()
        total_train_loss += loss.item()

        preds = torch.argmax(outputs, dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    train_loss = total_train_loss / len(train_loader)
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)

    # Validation
    model.eval()
    total_val_loss = 0
    all_preds, all_labels = [], []
    with torch.no_grad():
        for batch in tqdm(val_loader, desc="Evaluating"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)
            outputs = model(input_ids, attention_mask)
            loss = loss_fn(outputs, labels)
            total_val_loss += loss.item()
            preds = torch.argmax(outputs, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    val_loss = total_val_loss / len(val_loader)
    val_acc = np.mean(np.array(all_preds) == np.array(all_labels))
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)

    print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f}")
    print(f"Val   Loss: {val_loss:.4f} | Val   Acc: {val_acc:.4f}")

    # Save best model
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_epoch = epoch
        torch.save(model.state_dict(), modelPath)
        print(f"Saved new best model: {modelPath}")
        early_stop_counter = 0
    else:
        early_stop_counter += 1
        print(f"Early stop counter: {early_stop_counter}/{patience}")

    if early_stop_counter >= patience:
        print(f"\nEarly stopping at epoch {epoch+1}. Best epoch was {best_epoch+1}.")
        break

# === Plot Loss & Accuracy ===
epochs = range(1, len(train_losses) + 1)
plt.figure(figsize=(8, 5))
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, val_losses, label='Validation Loss')
plt.axvline(best_epoch + 1, linestyle='--', color='r', label='Best Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()
plt.grid(True)
plt.savefig(loss_graph_path)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(epochs, train_accuracies, label='Train Accuracy')
plt.plot(epochs, val_accuracies, label='Validation Accuracy')
plt.axvline(best_epoch + 1, linestyle='--', color='r', label='Best Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()
plt.grid(True)
plt.savefig(accuracy_graph_path)
plt.show()

# === Load best model and evaluate on test set ===
model.load_state_dict(torch.load(modelPath))
model.eval()

def evaluate(loader):
    model.eval()
    total_loss = 0
    all_preds, all_labels = [], []
    with torch.no_grad():
        for batch in tqdm(loader, desc="Evaluating"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)
            outputs = model(input_ids, attention_mask)
            loss = loss_fn(outputs, labels)
            total_loss += loss.item()
            preds = torch.argmax(outputs, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    acc = np.mean(np.array(all_preds) == np.array(all_labels))
    return total_loss / len(loader), acc, all_preds, all_labels

print(f"\n🔍 Final Evaluation on Test Set ({', '.join(test_categories)}):")
test_loss, test_acc, test_preds, test_labels = evaluate(test_loader)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}")

# Confusion Matrix & Classification Report
class_names = ["human", "AI"]
cm = confusion_matrix(test_labels, test_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap="Blues", xticks_rotation=45)
plt.title(f"Test Confusion Matrix ({', '.join(test_categories)})")
plt.grid(False)
plt.savefig(confusion_matrix_path)
plt.show()

print("\nClassification Report:")
print(classification_report(test_labels, test_preds, target_names=class_names, digits=4))
# Out:
# /tmp/ipykernel_10/369720376.py:61: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_names, y=counts.values, ax=axs[i], palette="pastel")
# /tmp/ipykernel_10/369720376.py:61: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_names, y=counts.values, ax=axs[i], palette="pastel")
# /tmp/ipykernel_10/369720376.py:61: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_names, y=counts.values, ax=axs[i], palette="pastel")
# Epoch 1/50
# Training: 100%|██████████| 507/507 [03:45<00:00,  2.25it/s]
# Evaluating:   0%|          | 0/57 [00:00<?, ?it/s]/usr/local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:508: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. We recommend specifying layout=torch.jagged when constructing a nested tensor, as this layout receives active development, has better operator coverage, and works with torch.compile. (Triggered internally at /pytorch/aten/src/ATen/NestedTensorImpl.cpp:178.)
#   output = torch._nested_tensor_from_mask(
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.12it/s]
# Train Loss: 0.5544 | Train Acc: 0.7171
# Val   Loss: 0.3334 | Val   Acc: 0.9211
# Saved new best model: best_model_train_novels_stories_poems_test_essays.pt
#
# Epoch 2/50
# Training: 100%|██████████| 507/507 [03:46<00:00,  2.24it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.10it/s]
# Train Loss: 0.3199 | Train Acc: 0.9269
# Val   Loss: 0.2885 | Val   Acc: 0.9489
# Saved new best model: best_model_train_novels_stories_poems_test_essays.pt
#
# Epoch 3/50
# Training: 100%|██████████| 507/507 [03:46<00:00,  2.24it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.12it/s]
# Train Loss: 0.2762 | Train Acc: 0.9570
# Val   Loss: 0.2704 | Val   Acc: 0.9611
# Saved new best model: best_model_train_novels_stories_poems_test_essays.pt
#
# Epoch 4/50
# Training: 100%|██████████| 507/507 [03:43<00:00,  2.27it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.18it/s]
# Train Loss: 0.2630 | Train Acc: 0.9651
# Val   Loss: 0.2583 | Val   Acc: 0.9667
# Saved new best model: best_model_train_novels_stories_poems_test_essays.pt
#
# Epoch 5/50
# Training: 100%|██████████| 507/507 [03:42<00:00,  2.28it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.34it/s]
# Train Loss: 0.2544 | Train Acc: 0.9695
# Val   Loss: 0.2830 | Val   Acc: 0.9556
# Early stop counter: 1/8
#
# Epoch 6/50
# Training: 100%|██████████| 507/507 [03:42<00:00,  2.28it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.16it/s]
# Train Loss: 0.2430 | Train Acc: 0.9765
# Val   Loss: 0.2822 | Val   Acc: 0.9533
# Early stop counter: 2/8
#
# Epoch 7/50
# Training: 100%|██████████| 507/507 [03:42<00:00,  2.27it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.12it/s]
# Train Loss: 0.2344 | Train Acc: 0.9815
# Val   Loss: 0.2533 | Val   Acc: 0.9744
# Saved new best model: best_model_train_novels_stories_poems_test_essays.pt
#
# Epoch 8/50
# Training: 100%|██████████| 507/507 [03:43<00:00,  2.27it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.11it/s]
# Train Loss: 0.2286 | Train Acc: 0.9853
# Val   Loss: 0.2549 | Val   Acc: 0.9744
# Early stop counter: 1/8
#
# Epoch 9/50
# Training: 100%|██████████| 507/507 [03:42<00:00,  2.28it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.07it/s]
# Train Loss: 0.2223 | Train Acc: 0.9888
# Val   Loss: 0.2648 | Val   Acc: 0.9700
# Early stop counter: 2/8
#
# Epoch 10/50
# Training: 100%|██████████| 507/507 [03:42<00:00,  2.27it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.21it/s]
# Train Loss: 0.2211 | Train Acc: 0.9893
# Val   Loss: 0.2539 | Val   Acc: 0.9744
# Early stop counter: 3/8
#
# Epoch 11/50
# Training: 100%|██████████| 507/507 [03:42<00:00,  2.28it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.12it/s]
# Train Loss: 0.2184 | Train Acc: 0.9906
# Val   Loss: 0.2486 | Val   Acc: 0.9783
# Saved new best model: best_model_train_novels_stories_poems_test_essays.pt
#
# Epoch 12/50
# Training: 100%|██████████| 507/507 [03:42<00:00,  2.28it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.02it/s]
# Train Loss: 0.2182 | Train Acc: 0.9913
# Val   Loss: 0.2753 | Val   Acc: 0.9644
# Early stop counter: 1/8
#
# Epoch 13/50
# Training: 100%|██████████| 507/507 [03:43<00:00,  2.27it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.09it/s]
# Train Loss: 0.2122 | Train Acc: 0.9944
# Val   Loss: 0.2622 | Val   Acc: 0.9744
# Early stop counter: 2/8
#
# Epoch 14/50
# Training: 100%|██████████| 507/507 [03:43<00:00,  2.27it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.01it/s]
# Train Loss: 0.2138 | Train Acc: 0.9935
# Val   Loss: 0.2571 | Val   Acc: 0.9722
# Early stop counter: 3/8
#
# Epoch 15/50
# Training: 100%|██████████| 507/507 [03:46<00:00,  2.24it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.16it/s]
# Train Loss: 0.2103 | Train Acc: 0.9954
# Val   Loss: 0.2633 | Val   Acc: 0.9711
# Early stop counter: 4/8
#
# Epoch 16/50
# Training: 100%|██████████| 507/507 [03:42<00:00,  2.28it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.19it/s]
# Train Loss: 0.2125 | Train Acc: 0.9943
# Val   Loss: 0.2740 | Val   Acc: 0.9667
# Early stop counter: 5/8
#
# Epoch 17/50
# Training: 100%|██████████| 507/507 [03:46<00:00,  2.24it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.10it/s]
# Train Loss: 0.2071 | Train Acc: 0.9969
# Val   Loss: 0.2599 | Val   Acc: 0.9733
# Early stop counter: 6/8
#
# Epoch 18/50
# Training: 100%|██████████| 507/507 [03:46<00:00,  2.24it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.05it/s]
# Train Loss: 0.2080 | Train Acc: 0.9961
# Val   Loss: 0.2533 | Val   Acc: 0.9767
# Early stop counter: 7/8
#
# Epoch 19/50
# Training: 100%|██████████| 507/507 [03:46<00:00,  2.24it/s]
# Evaluating: 100%|██████████| 57/57 [00:12<00:00,  4.72it/s]
# Train Loss: 0.2074 | Train Acc: 0.9965
# Val   Loss: 0.2566 | Val   Acc: 0.9750
# Early stop counter: 8/8
#
# Early stopping at epoch 19. Best epoch was 11.
# 🔍 Final Evaluation on Test Set (essays):
# Evaluating: 100%|██████████| 188/188 [00:38<00:00,  4.94it/s]
# Test Loss: 0.8695, Test Accuracy: 0.7168
# Classification Report:
#               precision    recall  f1-score   support
#
#        human     0.6578    0.9040    0.7615      3000
#           AI     0.8466    0.5297    0.6516      3000
#
#     accuracy                         0.7168      6000
#    macro avg     0.7522    0.7168    0.7066      6000
# weighted avg     0.7522    0.7168    0.7066      6000

# %% [markdown]
# ## Test on Stories

# %%
import pandas as pd
import os
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
from tokenizers import ByteLevelBPETokenizer
import torch.nn as nn
from transformers import get_cosine_schedule_with_warmup

# === Load Data ===
df = pd.read_csv("/kaggle/input/fianl-dataset/final_dataset.csv")

# Keep only "human" and "ai" labels
df = df[df['label'].isin(['human', 'ai'])]
label_map = {"human": 0, "ai": 1}
df["label"] = df["label"].map(label_map)

# === Split based on 'category' ===
train_categories = ["novels", "essays", "poems"]
test_categories  = ["stories"]

train_df = df[df["category"].isin(train_categories)]
test_df  = df[df["category"].isin(test_categories)]

# Split validation (10% from training set)
train_texts, val_texts, train_labels, val_labels = train_test_split(
    train_df["text"].tolist(),
    train_df["label"].tolist(),
    test_size=0.1,
    stratify=train_df["label"].tolist(),
    random_state=42
)

test_texts, test_labels = test_df["text"].tolist(), test_df["label"].tolist()

# === Prepare dynamic naming ===
train_cat_str = "_".join(train_categories)
test_cat_str  = "_".join(test_categories)

modelPath = f"best_model_train_{train_cat_str}_test_{test_cat_str}.pt"
loss_graph_path = f"loss_graph_train_{train_cat_str}_test_{test_cat_str}.png"
accuracy_graph_path = f"accuracy_graph_train_{train_cat_str}_test_{test_cat_str}.png"
confusion_matrix_path = f"confusion_matrix_train_{train_cat_str}_test_{test_cat_str}.png"

# === Plot label distribution ===
splits = {
    "Train": train_labels,
    "Validation": val_labels,
    f"Test ({', '.join(test_categories)})": test_labels,
}

fig, axs = plt.subplots(1, 3, figsize=(15, 5))
for i, (split_name, split_labels) in enumerate(splits.items()):
    counts = pd.Series(split_labels).value_counts().sort_index()
    class_names = ['Human', 'AI']
    sns.barplot(x=class_names, y=counts.values, ax=axs[i], palette="pastel")
    axs[i].set_title(f"{split_name} Set")
    axs[i].set_ylabel("Count")
    axs[i].set_ylim(0, max(counts.values) * 1.2)
    for j, count in enumerate(counts.values):
        axs[i].text(j, count + 2, str(count), ha='center', va='bottom', fontsize=10)
plt.tight_layout()
plt.suptitle("Label Distribution Across Splits", fontsize=16, y=1.05)
plt.show()

# === Tokenizer ===
tokenizerPath = "tokenizer_path"
if not os.path.exists(tokenizerPath):
    os.makedirs(tokenizerPath)
    tokenizer = ByteLevelBPETokenizer()
    tokenizer.train_from_iterator(train_texts, vocab_size=30000, min_frequency=2,
                                  special_tokens=["[PAD]", "[UNK]", "[CLS]", "[SEP]"])
    tokenizer.save_model(tokenizerPath)
else:
    tokenizer = ByteLevelBPETokenizer(f"{tokenizerPath}/vocab.json", f"{tokenizerPath}/merges.txt")

# === Hyperparameters ===
max_length = 128
batch_size = 32
device = "cuda" if torch.cuda.is_available() else "cpu"
learning_rate = 2e-5
num_epochs = 50
patience = 8

# === Encode function ===
def encode_batch(texts):
    encodings = tokenizer.encode_batch(texts)
    input_ids, attention_masks = [], []
    for e in encodings:
        ids = e.ids[:max_length] + [0] * (max_length - len(e.ids)) if len(e.ids) < max_length else e.ids[:max_length]
        mask = [1] * min(len(e.ids), max_length) + [0] * (max_length - len(e.ids))
        input_ids.append(ids)
        attention_masks.append(mask)
    return torch.tensor(input_ids), torch.tensor(attention_masks)

# === Dataset ===
class BengaliTextDataset(Dataset):
    def __init__(self, texts, labels):
        self.input_ids, self.attention_mask = encode_batch(texts)
        self.labels = torch.tensor(labels)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return {
            "input_ids": self.input_ids[idx],
            "attention_mask": self.attention_mask[idx],
            "labels": self.labels[idx]
        }

train_dataset = BengaliTextDataset(train_texts, train_labels)
val_dataset   = BengaliTextDataset(val_texts, val_labels)
test_dataset  = BengaliTextDataset(test_texts, test_labels)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_dataset, batch_size=batch_size)
test_loader  = DataLoader(test_dataset, batch_size=batch_size)

# === Model ===
class CustomTransformer(nn.Module):
    def __init__(self, vocab_size, max_len=128, d_model=512, nhead=8,
                 num_layers=6, dim_feedforward=2048, num_classes=2):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, d_model)
        self.position_embedding = nn.Embedding(max_len, d_model)
        encoder_layer = nn.TransformerEncoderLayer(d_model, nhead, dim_feedforward,
                                                   dropout=0.3, batch_first=True)
        self.encoder = nn.TransformerEncoder(encoder_layer, num_layers)
        self.dropout = nn.Dropout(0.3)
        self.classifier = nn.Sequential(
            nn.Linear(d_model, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, num_classes)
        )

    def forward(self, input_ids, attention_mask):
        positions = torch.arange(0, input_ids.size(1), device=input_ids.device).unsqueeze(0)
        x = self.embedding(input_ids) + self.position_embedding(positions)
        x = self.encoder(x, src_key_padding_mask=~attention_mask.bool())
        x = self.dropout(x[:, 0])
        return self.classifier(x)

vocab_size = tokenizer.get_vocab_size()
model = CustomTransformer(vocab_size=vocab_size).to(device)
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
loss_fn = nn.CrossEntropyLoss(label_smoothing=0.1)

# Scheduler
warmup_steps = 500
total_steps = len(train_loader) * num_epochs
scheduler = get_cosine_schedule_with_warmup(optimizer, warmup_steps, total_steps)

# === Training ===
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []
best_val_acc = 0
best_epoch = 0
early_stop_counter = 0

for epoch in range(num_epochs):
    print(f"\nEpoch {epoch+1}/{num_epochs}")
    model.train()
    total_train_loss, correct, total = 0, 0, 0
    for batch in tqdm(train_loader, desc="Training"):
        optimizer.zero_grad()
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        outputs = model(input_ids, attention_mask)
        loss = loss_fn(outputs, labels)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()
        total_train_loss += loss.item()

        preds = torch.argmax(outputs, dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)

    train_loss = total_train_loss / len(train_loader)
    train_acc = correct / total
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)

    # Validation
    model.eval()
    total_val_loss = 0
    all_preds, all_labels = [], []
    with torch.no_grad():
        for batch in tqdm(val_loader, desc="Evaluating"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)
            outputs = model(input_ids, attention_mask)
            loss = loss_fn(outputs, labels)
            total_val_loss += loss.item()
            preds = torch.argmax(outputs, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    val_loss = total_val_loss / len(val_loader)
    val_acc = np.mean(np.array(all_preds) == np.array(all_labels))
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)

    print(f"Train Loss: {train_loss:.4f} | Train Acc: {train_acc:.4f}")
    print(f"Val   Loss: {val_loss:.4f} | Val   Acc: {val_acc:.4f}")

    # Save best model
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        best_epoch = epoch
        torch.save(model.state_dict(), modelPath)
        print(f"Saved new best model: {modelPath}")
        early_stop_counter = 0
    else:
        early_stop_counter += 1
        print(f"Early stop counter: {early_stop_counter}/{patience}")

    if early_stop_counter >= patience:
        print(f"\nEarly stopping at epoch {epoch+1}. Best epoch was {best_epoch+1}.")
        break

# === Plot Loss & Accuracy ===
epochs = range(1, len(train_losses) + 1)
plt.figure(figsize=(8, 5))
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, val_losses, label='Validation Loss')
plt.axvline(best_epoch + 1, linestyle='--', color='r', label='Best Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()
plt.grid(True)
plt.savefig(loss_graph_path)
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(epochs, train_accuracies, label='Train Accuracy')
plt.plot(epochs, val_accuracies, label='Validation Accuracy')
plt.axvline(best_epoch + 1, linestyle='--', color='r', label='Best Epoch')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy Curve')
plt.legend()
plt.grid(True)
plt.savefig(accuracy_graph_path)
plt.show()

# === Load best model and evaluate on test set ===
model.load_state_dict(torch.load(modelPath))
model.eval()

def evaluate(loader):
    model.eval()
    total_loss = 0
    all_preds, all_labels = [], []
    with torch.no_grad():
        for batch in tqdm(loader, desc="Evaluating"):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)
            outputs = model(input_ids, attention_mask)
            loss = loss_fn(outputs, labels)
            total_loss += loss.item()
            preds = torch.argmax(outputs, dim=1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    acc = np.mean(np.array(all_preds) == np.array(all_labels))
    return total_loss / len(loader), acc, all_preds, all_labels

print(f"\n🔍 Final Evaluation on Test Set ({', '.join(test_categories)}):")
test_loss, test_acc, test_preds, test_labels = evaluate(test_loader)
print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}")

# Confusion Matrix & Classification Report
class_names = ["human", "AI"]
cm = confusion_matrix(test_labels, test_preds)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
disp.plot(cmap="Blues", xticks_rotation=45)
plt.title(f"Test Confusion Matrix ({', '.join(test_categories)})")
plt.grid(False)
plt.savefig(confusion_matrix_path)
plt.show()

print("\nClassification Report:")
print(classification_report(test_labels, test_preds, target_names=class_names, digits=4))
# Out:
# /tmp/ipykernel_10/274093595.py:61: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_names, y=counts.values, ax=axs[i], palette="pastel")
# /tmp/ipykernel_10/274093595.py:61: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_names, y=counts.values, ax=axs[i], palette="pastel")
# /tmp/ipykernel_10/274093595.py:61: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=class_names, y=counts.values, ax=axs[i], palette="pastel")
# Epoch 1/50
# Training: 100%|██████████| 507/507 [03:44<00:00,  2.25it/s]
# Evaluating:   0%|          | 0/57 [00:00<?, ?it/s]/usr/local/lib/python3.10/site-packages/torch/nn/modules/transformer.py:508: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. We recommend specifying layout=torch.jagged when constructing a nested tensor, as this layout receives active development, has better operator coverage, and works with torch.compile. (Triggered internally at /pytorch/aten/src/ATen/NestedTensorImpl.cpp:178.)
#   output = torch._nested_tensor_from_mask(
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.29it/s]
# Train Loss: 0.6074 | Train Acc: 0.6624
# Val   Loss: 0.4029 | Val   Acc: 0.8822
# Saved new best model: best_model_train_novels_essays_poems_test_stories.pt
#
# Epoch 2/50
# Training: 100%|██████████| 507/507 [03:49<00:00,  2.21it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  4.89it/s]
# Train Loss: 0.3681 | Train Acc: 0.8953
# Val   Loss: 0.3031 | Val   Acc: 0.9361
# Saved new best model: best_model_train_novels_essays_poems_test_stories.pt
#
# Epoch 3/50
# Training: 100%|██████████| 507/507 [03:46<00:00,  2.23it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.25it/s]
# Train Loss: 0.3104 | Train Acc: 0.9328
# Val   Loss: 0.2872 | Val   Acc: 0.9478
# Saved new best model: best_model_train_novels_essays_poems_test_stories.pt
#
# Epoch 4/50
# Training: 100%|██████████| 507/507 [03:48<00:00,  2.22it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.18it/s]
# Train Loss: 0.2933 | Train Acc: 0.9443
# Val   Loss: 0.2917 | Val   Acc: 0.9506
# Saved new best model: best_model_train_novels_essays_poems_test_stories.pt
#
# Epoch 5/50
# Training: 100%|██████████| 507/507 [03:50<00:00,  2.20it/s]
# Evaluating: 100%|██████████| 57/57 [00:11<00:00,  5.17it/s]
# Train Loss: 0.2778 | Train Acc: 0.9535
# Val   Loss: 0.3081 | Val   Acc: 0.9428
# Early stop counter: 1/8
#
# Epoch 6/50
# Training: 100%|██████████| 507/507 [03:47<00:00,  2.23it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.35it/s]
# Train Loss: 0.2625 | Train Acc: 0.9649
# Val   Loss: 0.2757 | Val   Acc: 0.9578
# Saved new best model: best_model_train_novels_essays_poems_test_stories.pt
#
# Epoch 7/50
# Training: 100%|██████████| 507/507 [03:45<00:00,  2.25it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.34it/s]
# Train Loss: 0.2581 | Train Acc: 0.9684
# Val   Loss: 0.2724 | Val   Acc: 0.9622
# Saved new best model: best_model_train_novels_essays_poems_test_stories.pt
#
# Epoch 8/50
# Training: 100%|██████████| 507/507 [03:47<00:00,  2.23it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.31it/s]
# Train Loss: 0.2469 | Train Acc: 0.9742
# Val   Loss: 0.2776 | Val   Acc: 0.9617
# Early stop counter: 1/8
#
# Epoch 9/50
# Training: 100%|██████████| 507/507 [03:47<00:00,  2.23it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.39it/s]
# Train Loss: 0.2423 | Train Acc: 0.9768
# Val   Loss: 0.2775 | Val   Acc: 0.9567
# Early stop counter: 2/8
#
# Epoch 10/50
# Training: 100%|██████████| 507/507 [03:47<00:00,  2.23it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.31it/s]
# Train Loss: 0.2351 | Train Acc: 0.9813
# Val   Loss: 0.2853 | Val   Acc: 0.9606
# Early stop counter: 3/8
#
# Epoch 11/50
# Training: 100%|██████████| 507/507 [03:46<00:00,  2.24it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.37it/s]
# Train Loss: 0.2299 | Train Acc: 0.9849
# Val   Loss: 0.2679 | Val   Acc: 0.9672
# Saved new best model: best_model_train_novels_essays_poems_test_stories.pt
#
# Epoch 12/50
# Training: 100%|██████████| 507/507 [03:44<00:00,  2.26it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.31it/s]
# Train Loss: 0.2238 | Train Acc: 0.9878
# Val   Loss: 0.2835 | Val   Acc: 0.9639
# Early stop counter: 1/8
#
# Epoch 13/50
# Training: 100%|██████████| 507/507 [03:46<00:00,  2.24it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.34it/s]
# Train Loss: 0.2177 | Train Acc: 0.9909
# Val   Loss: 0.2968 | Val   Acc: 0.9600
# Early stop counter: 2/8
#
# Epoch 14/50
# Training: 100%|██████████| 507/507 [03:50<00:00,  2.20it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.21it/s]
# Train Loss: 0.2188 | Train Acc: 0.9907
# Val   Loss: 0.3027 | Val   Acc: 0.9572
# Early stop counter: 3/8
#
# Epoch 15/50
# Training: 100%|██████████| 507/507 [03:47<00:00,  2.22it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.22it/s]
# Train Loss: 0.2123 | Train Acc: 0.9940
# Val   Loss: 0.3041 | Val   Acc: 0.9578
# Early stop counter: 4/8
#
# Epoch 16/50
# Training: 100%|██████████| 507/507 [03:47<00:00,  2.23it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.22it/s]
# Train Loss: 0.2108 | Train Acc: 0.9951
# Val   Loss: 0.2923 | Val   Acc: 0.9617
# Early stop counter: 5/8
#
# Epoch 17/50
# Training: 100%|██████████| 507/507 [03:48<00:00,  2.22it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.40it/s]
# Train Loss: 0.2090 | Train Acc: 0.9959
# Val   Loss: 0.2809 | Val   Acc: 0.9661
# Early stop counter: 6/8
#
# Epoch 18/50
# Training: 100%|██████████| 507/507 [03:46<00:00,  2.24it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.25it/s]
# Train Loss: 0.2068 | Train Acc: 0.9969
# Val   Loss: 0.2986 | Val   Acc: 0.9589
# Early stop counter: 7/8
#
# Epoch 19/50
# Training: 100%|██████████| 507/507 [03:44<00:00,  2.26it/s]
# Evaluating: 100%|██████████| 57/57 [00:10<00:00,  5.35it/s]
# Train Loss: 0.2110 | Train Acc: 0.9945
# Val   Loss: 0.2861 | Val   Acc: 0.9644
# Early stop counter: 8/8
#
# Early stopping at epoch 19. Best epoch was 11.
# 🔍 Final Evaluation on Test Set (stories):
# Evaluating: 100%|██████████| 188/188 [00:35<00:00,  5.27it/s]
# Test Loss: 0.3517, Test Accuracy: 0.9267
# Classification Report:
#               precision    recall  f1-score   support
#
#        human     0.9103    0.9467    0.9281      3000
#           AI     0.9444    0.9067    0.9252      3000
#
#     accuracy                         0.9267      6000
#    macro avg     0.9274    0.9267    0.9266      6000
# weighted avg     0.9274    0.9267    0.9266      6000
